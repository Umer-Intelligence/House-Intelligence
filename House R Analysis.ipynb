# %%
#In this file we are going to analyze the Houses dataset using R

# %% [markdown]
# # Loading Libraries

# %%
library(dplyr)
library(ggplot2)
# Out:
# Warning message:
# "package 'dplyr' was built under R version 4.1.0"
#
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# # Viewing dataset

# %%
House <- read.csv('C:/Desktop/House/Houses.csv')
House
# Out:
#      price     bedrooms bathrooms sqft_living sqft_lot floors waterfront view
# 1     313000   3        1.50      1340         7912    1.5    0          0
# 2    2384000   5        2.50      3650         9050    2.0    0          4
# 3     342000   3        2.00      1930        11947    1.0    0          0
# 4     420000   3        2.25      2000         8030    1.0    0          0
# 5     550000   4        2.50      1940        10500    1.0    0          0
# 6     490000   2        1.00       880         6380    1.0    0          0
# 7     335000   2        2.00      1350         2560    1.0    0          0
# 8     482000   4        2.50      2710        35868    2.0    0          0
# 9     452500   3        2.50      2430        88426    1.0    0          0
# 10    640000   4        2.00      1520         6200    1.5    0          0
# 11    463000   3        1.75      1710         7320    1.0    0          0
# ...

# %% [markdown]
# # Analyzing dataset

# %%
#To find the relationship between number of floors and bedrooms

# %%
House %>% select('bedrooms','floors')
# Out:
#      bedrooms floors
# 1    3        1.5
# 2    5        2.0
# 3    3        1.0
# 4    3        1.0
# 5    4        1.0
# 6    2        1.0
# 7    2        1.0
# 8    4        2.0
# 9    3        1.0
# 10   4        1.5
# 11   3        1.0
# 12   4        1.5
# 13   3        1.0
# 14   3        1.0
# 15   5        1.5
# 16   3        1.0
# 17   3        1.0
# 18   4        2.0
# 19   3        1.0
# 20   3        1.0
# 21   3        2.0
# 22   4        1.0
# 23   3        2.5
# 24   4        2.0
# 25   4        1.0
# 26   3        1.0
# 27   3        1.0
# 28   4        1.5
# 29   5        2.0
# 30   3        1.0
# ...  ...      ...
# 4571 2        1.0
# 4572 4        1.5
# 4573 6        3.0
# 4574 3        2.0
# 4575 3        1.0
# 4576 5        2.0
# 4577 3        2.0
# 4578 2        1.0
# 4579 4        2.0
# 4580 2        1.0
# 4581 3        1.0
# 4582 3        1.5
# 4583 2        1.0
# 4584 4        1.0
# 4585 3        1.0
# 4586 3        1.5
# 4587 3        3.0
# ...

# %%
#To find the house and the city having the highest price.

# %%
House %>% select('city','price') %>% filter(price==max(price))
# Out:
#   city price
# 1 Kent 26590000

# %%
#To find the prices of houses over the years

# %%
House %>% group_by(House$yr_built) %>% summarise(price=mean(price))
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#     House$yr_built price
# 1   1900           701045.5
# 2   1901           506127.2
# 3   1902           854725.0
# 4   1903           513010.0
# 5   1904           501933.3
# 6   1905           782052.7
# 7   1906           596786.4
# 8   1907           583383.3
# 9   1908           516868.4
# 10  1909           821754.5
# 11  1910           637971.9
# 12  1911           509421.9
# 13  1912           581091.1
# 14  1913           819155.6
# 15  1914           864360.0
# 16  1915           619666.7
# 17  1916           587937.5
# 18  1917           688818.2
# 19  1918           530181.8
# 20  1919           525432.6
# 21  1920           491971.2
# 22  1921           670530.0
# 23  1922           484117.1
# 24  1923           679514.9
# 25  1924           572004.0
# 26  1925           570927.6
# 27  1926           586239.3
# 28  1927           627096.0
# 29  1928           648818.8
# 30  1929           623218.8
# ...

# %%
#To find the number of houses having respective condition

# %%
House %>% group_by(House$condition) %>% summarise(n())
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   House$condition n()
# 1 1                  6
# 2 2                 32
# 3 3               2875
# 4 4               1252
# 5 5                435

# %%
#To find the number of houses having waterfronts

# %%
House %>% group_by(waterfront) %>% summarise(n())
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   waterfront n()
# 1 0          4567
# 2 1            33

# %%
#To create a new column showing price per sqfeet of the house

# %%
House['Price per sqfeet'] = House$price/House$sqft_lot
House['Price per sqfeet']
# Out:
#      Price per sqfeet
# 1     39.560162
# 2    263.425414
# 3     28.626433
# 4     52.303861
# 5     52.380952
# 6     76.802508
# 7    130.859375
# 8     13.438162
# 9      5.117273
# 10   103.225806
# 11    63.251366
# 12   350.000000
# 13    39.517862
# 14    56.721057
# 15   126.582278
# 16    24.948560
# 17    62.537313
# 18    50.822846
# 19    44.033800
# 20    26.758782
# 21    70.901872
# 22    49.431818
# 23   398.218830
# 24    49.955142
# 25    77.586207
# 26    26.306073
# 27    84.350569
# 28    62.044444
# 29     9.997334
# 30   166.315789
# ...  ...
# 4571  90.77933
# 4572 114.70982
# 4573 268.40278
# 4574 563.70656
# 4575   0.00000
# 4576   0.00000
# 4577  33.06343
# 4578  62.59126
# 4579  53.14945
# 4580 113.69750
# 4581  37.40849
# 4582 112.66667
# 4583  87.32527
# 4584  32.72762
# 4585  48.48942
# 4586 146.21471
# 4587 400.25840
# 4588  28.17886
# 4589   0.00000
# 4590  20.55837
# 4591  45.69446
# 4592  68.87459
# 4593  30.96829
# 4594  62.90724
# 4595  29.15884
# ...

# %%
#To arrange the dataset in the increasing order of price

# %%
House %>% arrange(price)
# Out:
#      price    bedrooms bathrooms sqft_living sqft_lot floors waterfront view
# 1    0        3        1.75      1490         10125   1.0    0          0
# 2    0        4        2.75      2600          5390   1.0    0          0
# 3    0        6        2.75      3200          9200   1.0    0          2
# 4    0        5        3.50      3480         36615   2.0    0          0
# 5    0        5        1.50      1500          7112   1.0    0          0
# 6    0        4        4.00      3680         18804   2.0    0          0
# 7    0        2        2.50      2200        188200   1.0    0          3
# 8    0        4        2.25      2170         10500   1.0    0          2
# 9    0        5        4.50      4630          6324   2.0    0          0
# 10   0        5        4.00      4430          9000   2.0    0          0
# 11   0        4        4.50      5030         11023   2.0    0          2
# 12   0        4        1.50      2180         22870   1.0    0          0
# ...

# %%
#To find the number of houses having respective floors

# %%
House %>% group_by(House$floors) %>% summarise(n())
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   House$floors n()
# 1 1.0          2174
# 2 1.5           444
# 3 2.0          1811
# 4 2.5            41
# 5 3.0           128
# 6 3.5             2

# %% [markdown]
# # Visualizing Dataset

# %%
#To find the relationship between price and year_built

# %%
ggplot(data=House,aes(x=yr_built,y=price)) + geom_bar(stat='identity',color='yellow')
# Out:
# plot without title

# %%
#To find the freqency of number of floors

# %%
hist(x=House$floors,col='red')
# Out:
# Plot with title "Histogram of House$floors"

# %%
#To find the frquency of number of bedrooms

# %%
hist(x=House$bedrooms,col='green')
# Out:
# Plot with title "Histogram of House$bedrooms"

# %%
plot(x=House$floors,y=House$bedrooms,col='blue',cex=2)
# Out:
# plot without title

# %%
Data <- data.frame(condition=c(1,2,3,4,5),value=c(6,32,2875,1252,432))
ggplot(data=Data, aes(x="",y=value,fill=condition)) +
  geom_bar(stat="identity", width=1) +
  coord_polar("y", start=0)
# Out:
# plot without title
